# %% [markdown]
# <a href="https://colab.research.google.com/github/Hoopoe11/Lab/blob/main/zad_dom_z_lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

# %% [markdown]
# **Simple visualization and classification of the digits dataset**
# =============================================================
#
# Do a simple MLP classification of 28x28 MNIST dataset
#
# *Marcin Wolter*

# %%
#import packages and load datasets

import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml
from sklearn.neural_network import MLPClassifier
import numpy as np
from sklearn.model_selection import train_test_split


# Load data from https://www.openml.org/d/554
X, y = fetch_openml('mnist_784', version=1, return_X_y=True)
X = X / 255.


# split the data into training and validation sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=33, train_size=0.5)

# %% [markdown]
# Plot the data: images of digits
# -------------------------------
#
# Each data in a 28x28 image
#
# ![digits_1.png](data:image/png;base64,...)

# %%
# leave empty for time beeing

# %% [markdown]
# ## **Classify with MLP**

# %%
# tu musimy zdefiniować klasyfikator, wytrenowaći sprawdzić "score" dla 
# danych testowych
#Proponowane parametry sieci: ukryte warstwy [100,100],solver adam, verbose=10 
clf = MLPClassifier(hidden_layer_sizes=(100,100), solver='adam', verbose=10, validation_fraction=0.2, early_stopping=True)
                     
print(clf.fit(X_train, y_train))

# get score
score = clf.score(X_test, y_test)
print("Score = ",score)

# use the model to predict the labels of the test data
predicted = clf.predict(X_test)
expected = y_test
# Out:
# Iteration 1, loss = 0.58209239
# Validation score: 0.911571
# Iteration 2, loss = 0.22159279
# Validation score: 0.932714
# Iteration 3, loss = 0.16421139
# Validation score: 0.943143
# Iteration 4, loss = 0.13295965
# Validation score: 0.951571
# Iteration 5, loss = 0.10699597
# Validation score: 0.953571
# Iteration 6, loss = 0.08792822
# Validation score: 0.957286
# Iteration 7, loss = 0.07291840
# Validation score: 0.960286
# Iteration 8, loss = 0.06309465
# Validation score: 0.961429
# Iteration 9, loss = 0.05314183
# Validation score: 0.960714
# Iteration 10, loss = 0.04266787
# Validation score: 0.964714
# Iteration 11, loss = 0.03850525
# Validation score: 0.958429
# Iteration 12, loss = 0.03301091
# Validation score: 0.963714
# Iteration 13, loss = 0.02626973
# Validation score: 0.965000
# Iteration 14, loss = 0.02070243
# Validation score: 0.964714
# Iteration 15, loss = 0.01743162
# Validation score: 0.964714
# Iteration 16, loss = 0.01452740
# Validation score: 0.963571
# Iteration 17, loss = 0.01143208
# Validation score: 0.965571
# Iteration 18, loss = 0.00894149
# Validation score: 0.964143
# Iteration 19, loss = 0.00664587
# Validation score: 0.966143
# Iteration 20, loss = 0.00618612
# Validation score: 0.963429
# Iteration 21, loss = 0.00467266
# Validation score: 0.968143
# Iteration 22, loss = 0.00340821
# Validation score: 0.967714
# Iteration 23, loss = 0.00301889
# Validation score: 0.967143
# Iteration 24, loss = 0.00316819
# Validation score: 0.966857
# Iteration 25, loss = 0.00229421
# Validation score: 0.967000
# Iteration 26, loss = 0.00179133
# Validation score: 0.966429
# Iteration 27, loss = 0.00159374
# Validation score: 0.968000
# Iteration 28, loss = 0.00133111
# Validation score: 0.967143
# Iteration 29, loss = 0.00138111
# Validation score: 0.966714
# Iteration 30, loss = 0.00170670
# Validation score: 0.967000
# Iteration 31, loss = 0.00112563
# Validation score: 0.966429
# Iteration 32, loss = 0.00097417
# Validation score: 0.968286
# Iteration 33, loss = 0.00143615
# Validation score: 0.965000
# Iteration 34, loss = 0.04918985
# Validation score: 0.961429
# Iteration 35, loss = 0.01504295
# Validation score: 0.965286
# Iteration 36, loss = 0.00645203
# Validation score: 0.966286
# Iteration 37, loss = 0.00178616
# Validation score: 0.968857
# Iteration 38, loss = 0.00100975
# Validation score: 0.968571
# Iteration 39, loss = 0.00078009
# Validation score: 0.968714
# Iteration 40, loss = 0.00070060
# Validation score: 0.968571
# Iteration 41, loss = 0.00064461
# Validation score: 0.968571
# Iteration 42, loss = 0.00059734
# Validation score: 0.968000
# Iteration 43, loss = 0.00056467
# Validation score: 0.968714
# Iteration 44, loss = 0.00053492
# Validation score: 0.968286
# Iteration 45, loss = 0.00051046
# Validation score: 0.969000
# Iteration 46, loss = 0.00048940
# Validation score: 0.968571
# Iteration 47, loss = 0.00047200
# Validation score: 0.969429
# Iteration 48, loss = 0.00045557
# Validation score: 0.969286
# Iteration 49, loss = 0.00043838
# Validation score: 0.968857
# Iteration 50, loss = 0.00042793
# Validation score: 0.969857
# Iteration 51, loss = 0.00041401
# Validation score: 0.969429
# Iteration 52, loss = 0.00040351
# Validation score: 0.969571
# Iteration 53, loss = 0.00038997
# Validation score: 0.970000
# Iteration 54, loss = 0.00038186
# Validation score: 0.969714
# Iteration 55, loss = 0.00037151
# Validation score: 0.969857
# Iteration 56, loss = 0.00036342
# Validation score: 0.969714
# Iteration 57, loss = 0.00035488
# Validation score: 0.969714
# Iteration 58, loss = 0.00034724
# Validation score: 0.969429
# Iteration 59, loss = 0.00034058
# Validation score: 0.969571
# Iteration 60, loss = 0.00033436
# Validation score: 0.969857
# Iteration 61, loss = 0.00032831
# Validation score: 0.969429
# Iteration 62, loss = 0.00032162
# Validation score: 0.969286
# Iteration 63, loss = 0.00031664
# Validation score: 0.969714
# Iteration 64, loss = 0.00031150
# Validation score: 0.969857
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=True, epsilon=1e-08,
#               hidden_layer_sizes=(100, 100), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=200,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=None, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.2, verbose=10,
#               warm_start=False)
# Score =  0.9701714285714286

# %% [markdown]
# # **Plot loss**
# ![loss_1.png](data:image/png;base64,...)

# %%
# tu rysujemy loss i validation score
# zostawiamy na razie puste
fig=plt.figure(figsize=(7,7))

plt.plot(clf.loss_curve_)
#Warning: thiscan be usedonly if early_stopping=True
print(clf.validation_scores_)
plt.plot(np.asarray(clf.validation_scores_))

plt.show()
# Out:
# [0.9115714285714286, 0.9327142857142857, 0.9431428571428572, 0.9515714285714286, 0.9535714285714286, 0.9572857142857143, 0.9602857142857143, 0.9614285714285714, 0.9607142857142857, 0.9647142857142857, 0.9584285714285714, 0.9637142857142857, 0.965, 0.9647142857142857, 0.9647142857142857, 0.9635714285714285, 0.9655714285714285, 0.9641428571428572, 0.9661428571428572, 0.9634285714285714, 0.9681428571428572, 0.9677142857142857, 0.9671428571428572, 0.9668571428571429, 0.967, 0.9664285714285714, 0.968, 0.9671428571428572, 0.9667142857142857, 0.967, 0.9664285714285714, 0.9682857142857143, 0.965, 0.9614285714285714, 0.9652857142857143, 0.9662857142857143, 0.9688571428571429, 0.9685714285714285, 0.9687142857142857, 0.9685714285714285, 0.9685714285714285, 0.968, 0.9687142857142857, 0.9682857142857143, 0.969, 0.9685714285714285, 0.9694285714285714, 0.9692857142857143, 0.9688571428571429, 0.9698571428571429, 0.9694285714285714, 0.9695714285714285, 0.97, 0.9697142857142858, 0.9698571428571429, 0.9697142857142858, 0.9697142857142858, 0.9694285714285714, 0.9695714285714285, 0.9698571428571429, 0.9694285714285714, 0.9692857142857143, 0.9697142857142858, 0.9698571428571429]

# %% [markdown]
# #**Plot results**
# ![digits_2.png](data:image/png;base64,...)

# %%
# Plot the prediction

# Tu rysujemy cyfry z wynikami
# na razie zostawiamy puste

# %%
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(15, 15)) # figure size in inches
 
for i in range(25):
 ax = fig.add_subplot(5, 5, i + 1)
 ax.imshow(X_test[i].reshape(28,28), cmap=plt.cm.gray, interpolation='nearest')
 if expected[i]==predicted[i]:
    ax.text(0, 7, str(expected[i])+" "+str(predicted[i]), color='white')
 else:
    ax.text(0, 7, str(expected[i])+" "+str(predicted[i]), color='red')

# %% [markdown]
# Print the classification report

# %%
#from sklearn import metrics
#print(metrics.classification_report(expected, predicted))

# %%
from sklearn import metrics
print(metrics.classification_report(expected, predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      3409
#            1       0.98      0.99      0.98      3949
#            2       0.97      0.97      0.97      3500
#            3       0.96      0.96      0.96      3557
#            4       0.97      0.97      0.97      3398
#            5       0.97      0.96      0.96      3203
#            6       0.97      0.98      0.98      3444
#            7       0.97      0.97      0.97      3637
#            8       0.96      0.96      0.96      3437
#            9       0.96      0.96      0.96      3466
#
#     accuracy                           0.97     35000
#    macro avg       0.97      0.97      0.97     35000
# weighted avg       0.97      0.97      0.97     35000

# %% [markdown]
# # **Print the confusion matrix (expected true label vs. the reconstructed label)**

# %%
print(metrics.confusion_matrix(expected, predicted))
# Out:
# [[3352    0    7    3    1    5   22    6    8    5]
#  [   1 3891   11   10    5    3    3   12   10    3]
#  [  12   11 3392   16   10    0   13   26   16    4]
#  [   3    5   22 3427    3   34    1   18   27   17]
#  [   2    5   14    1 3307    2   13    9    9   36]
#  [  11    7    4   37    5 3064   23    9   25   18]
#  [   9    7    1    1   17   16 3380    2   11    0]
#  [   4   17   21    9   13    2    1 3534    3   33]
#  [  13   20   17   33    5   16   14    9 3292   18]
#  [   9    9    6   27   35   12    1   32   18 3317]]

# %% [markdown]
# # **Repeat the same classification for faces**

# %%
####################################################
# Load dataset with faces
from sklearn.datasets import fetch_lfw_people

# #############################################################################
# Download the data, if not already on disk and load it as numpy arrays

lfw_people = fetch_lfw_people(min_faces_per_person=100, resize=0.50)  
print(lfw_people.images.shape)


# introspect the images arrays to find the shapes (for plotting)
n_samples, h, w = lfw_people.images.shape

# for machine learning we use the 2 data directly (as relative pixel
# positions info is ignored by this model)
X = lfw_people.data
n_features = X.shape[1]

# the label to predict is the id of the person
y = lfw_people.target
# to get real names, not digits
target_names = lfw_people.target_names

# split into a training and testing set
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42)

print("Image shape: ",X_train.shape)
# dimension of face image
nfaces, h, w = lfw_people.images.shape
print("Image shape: ", h, w)
# Out:
# Downloading LFW metadata: https://ndownloader.figshare.com/files/5976012
# Downloading LFW metadata: https://ndownloader.figshare.com/files/5976009
# Downloading LFW metadata: https://ndownloader.figshare.com/files/5976006
# Downloading LFW data (~200MB): https://ndownloader.figshare.com/files/5976015
# (1140, 62, 47)
# Image shape:  (855, 2914)
# Image shape:  62 47

# %% [markdown]
# Plot the data: images of faces
# -------------------------------
#
# Each data in a 32x24 image
#
# ![faces_1.png](data:image/png;base64,...)

# %%
#import packages and load datasets

import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml
from sklearn.neural_network import MLPClassifier
import numpy as np
from sklearn.model_selection import train_test_split

# tu rysujemy twarze
# tu rysujemy twarze
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(16, 16)) # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)
 
for i in range(100):
 ax = fig.add_subplot(10, 10, i + 1, xticks=[], yticks=[])
 ax.imshow(X_test[i].reshape(h,w), cmap=plt.cm.gray, interpolation='nearest')
 # label the image with the target value
 ax.text(0, 7, str(target_names[y_test[i]]))

# %% [markdown]
# ## **Classify with MLP**

# %%
# train the model
# tu musimy zdefiniować klasyfikator, wytrenowaći sprawdzić "score" dla 
# danych testowych
#Proponowane parametry sieci: ukryte warstwy [100,100],solver adam, verbose=10 
clf = MLPClassifier(hidden_layer_sizes=(100,100), solver='adam', alpha=0.1, verbose=10, validation_fraction=0.2, early_stopping=True,n_iter_no_change=50)
                     
print(clf.fit(X_train, y_train))

# get score
score = clf.score(X_test, y_test)
print("Score = ",score)

# use the model to predict the labels of the test data
predicted = clf.predict(X_test)
expected = y_test
# Out:
# Iteration 1, loss = inf
# Validation score: 0.140351
# Iteration 2, loss = 160.65255273
# Validation score: 0.438596
# Iteration 3, loss = 92.23934161
# Validation score: 0.245614
# Iteration 4, loss = 88.77743821
# Validation score: 0.274854
# Iteration 5, loss = 94.75444522
# Validation score: 0.450292
# Iteration 6, loss = 53.56863739
# Validation score: 0.491228
# Iteration 7, loss = 27.13768742
# Validation score: 0.473684
# Iteration 8, loss = 22.56642315
# Validation score: 0.461988
# Iteration 9, loss = 37.63971808
# Validation score: 0.456140
# Iteration 10, loss = 45.32453177
# Validation score: 0.426901
# Iteration 11, loss = 36.03664499
# Validation score: 0.345029
# Iteration 12, loss = 26.89226911
# Validation score: 0.257310
# Iteration 13, loss = 28.87277687
# Validation score: 0.362573
# Iteration 14, loss = 23.27801462
# Validation score: 0.432749
# Iteration 15, loss = 30.51756310
# Validation score: 0.508772
# Iteration 16, loss = 25.76398622
# Validation score: 0.508772
# Iteration 17, loss = 31.57271057
# Validation score: 0.467836
# Iteration 18, loss = 27.54404825
# Validation score: 0.467836
# Iteration 19, loss = 42.17304872
# Validation score: 0.473684
# Iteration 20, loss = 48.69188210
# Validation score: 0.608187
# Iteration 21, loss = 35.94208064
# Validation score: 0.473684
# Iteration 22, loss = 58.31397346
# Validation score: 0.532164
# Iteration 23, loss = 28.60864240
# Validation score: 0.467836
# Iteration 24, loss = 27.59387181
# Validation score: 0.350877
# Iteration 25, loss = 16.64597239
# Validation score: 0.473684
# Iteration 26, loss = 10.77288812
# Validation score: 0.573099
# Iteration 27, loss = 9.15490821
# Validation score: 0.368421
# Iteration 28, loss = 10.91990939
# Validation score: 0.485380
# Iteration 29, loss = 7.67498352
# Validation score: 0.573099
# Iteration 30, loss = 6.01946682
# Validation score: 0.590643
# Validation score: 0.497076
# Iteration 129, loss = 49.12191211
# Validation score: 0.532164
# Iteration 130, loss = 35.74129367
# Validation score: 0.684211
# Iteration 131, loss = 30.35697503
# Validation score: 0.479532
# Iteration 132, loss = 28.94797374
# Validation score: 0.274854
# Iteration 133, loss = 17.79232713
# Validation score: 0.555556
# Iteration 134, loss = 17.08772311
# Validation score: 0.502924
# Iteration 135, loss = 16.03214237
# Validation score: 0.684211
# Iteration 136, loss = 7.61916235
# Validation score: 0.561404
# Iteration 137, loss = 6.08265545
# Validation score: 0.637427
# Iteration 138, loss = 5.21001245
# Validation score: 0.707602
# Iteration 139, loss = 2.93323633
# Validation score: 0.561404
# Iteration 140, loss = 2.66964538
# Validation score: 0.748538
# Iteration 141, loss = 2.07982149
# Validation score: 0.742690
# Iteration 142, loss = 1.22081730
# Validation score: 0.725146
# Iteration 143, loss = 1.14130851
# Validation score: 0.707602
# Iteration 144, loss = 1.31301623
# Validation score: 0.713450
# Iteration 145, loss = 1.19934969
# Validation score: 0.736842
# Iteration 146, loss = 1.04224777
# Validation score: 0.690058
# Iteration 147, loss = 1.05801026
# Validation score: 0.766082
# Iteration 148, loss = 0.87150753
# Validation score: 0.760234
# Validation score did not improve more than tol=0.000100 for 50 consecutive epochs. Stopping.
# MLPClassifier(activation='relu', alpha=0.1, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=True, epsilon=1e-08,
#               hidden_layer_sizes=(100, 100), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=200,
#               momentum=0.9, n_iter_no_change=50, nesterovs_momentum=True,
#               power_t=0.5, random_state=None, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.2, verbose=10,
#               warm_start=False)
# Score =  0.8421052631578947

# %% [markdown]
# # **Plot loss**

# %%
# tu rysujemy loss i validation score
# zostawiamy na razie puste
fig=plt.figure(figsize=(7,7))

plt.plot(clf.loss_curve_)
#Warning: thiscan be usedonly if early_stopping=True
print(clf.validation_scores_)
plt.plot(np.asarray(clf.validation_scores_))

plt.show()
# Out:
# [0.14035087719298245, 0.43859649122807015, 0.24561403508771928, 0.27485380116959063, 0.4502923976608187, 0.49122807017543857, 0.47368421052631576, 0.4619883040935672, 0.45614035087719296, 0.4269005847953216, 0.34502923976608185, 0.2573099415204678, 0.36257309941520466, 0.4327485380116959, 0.5087719298245614, 0.5087719298245614, 0.4678362573099415, 0.4678362573099415, 0.47368421052631576, 0.6081871345029239, 0.47368421052631576, 0.5321637426900585, 0.4678362573099415, 0.3508771929824561, 0.47368421052631576, 0.5730994152046783, 0.3684210526315789, 0.4853801169590643, 0.5730994152046783, 0.5906432748538012, 0.5614035087719298, 0.631578947368421, 0.6198830409356725, 0.5146198830409356, 0.6900584795321637, 0.6666666666666666, 0.6432748538011696, 0.6900584795321637, 0.695906432748538, 0.5964912280701754, 0.6140350877192983, 0.5789473684210527, 0.5847953216374269, 0.6900584795321637, 0.7017543859649122, 0.6023391812865497, 0.6257309941520468, 0.5497076023391813, 0.5847953216374269, 0.6549707602339181, 0.6783625730994152, 0.23391812865497075, 0.5847953216374269, 0.27485380116959063, 0.6549707602339181, 0.6023391812865497, 0.5672514619883041, 0.6549707602339181, 0.6608187134502924, 0.5497076023391813, 0.5847953216374269, 0.672514619883041, 0.6081871345029239, 0.5847953216374269, 0.6023391812865497, 0.5964912280701754, 0.5087719298245614, 0.7017543859649122, 0.7426900584795322, 0.6842105263157895, 0.7192982456140351, 0.7134502923976608, 0.5672514619883041, 0.6374269005847953, 0.6140350877192983, 0.7251461988304093, 0.6257309941520468, 0.7543859649122807, 0.7894736842105263, 0.7309941520467836, 0.7426900584795322, 0.7192982456140351, 0.7485380116959064, 0.6900584795321637, 0.7660818713450293, 0.7251461988304093, 0.7485380116959064, 0.7426900584795322, 0.672514619883041, 0.7543859649122807, 0.6608187134502924, 0.7309941520467836, 0.7251461988304093, 0.7426900584795322, 0.7192982456140351, 0.7368421052631579, 0.7953216374269005, 0.7426900584795322, 0.6549707602339181, 0.672514619883041, 0.7251461988304093, 0.7543859649122807, 0.6374269005847953, 0.6783625730994152, 0.6608187134502924, 0.7192982456140351, 0.7426900584795322, 0.7602339181286549, 0.7660818713450293, 0.7134502923976608, 0.7426900584795322, 0.7309941520467836, 0.783625730994152, 0.631578947368421, 0.7134502923976608, 0.6257309941520468, 0.7485380116959064, 0.6666666666666666, 0.672514619883041, 0.6549707602339181, 0.5964912280701754, 0.7076023391812866, 0.5847953216374269, 0.7309941520467836, 0.5263157894736842, 0.631578947368421, 0.2631578947368421, 0.49707602339181284, 0.5321637426900585, 0.6842105263157895, 0.47953216374269003, 0.27485380116959063, 0.5555555555555556, 0.5029239766081871, 0.6842105263157895, 0.5614035087719298, 0.6374269005847953, 0.7076023391812866, 0.5614035087719298, 0.7485380116959064, 0.7426900584795322, 0.7251461988304093, 0.7076023391812866, 0.7134502923976608, 0.7368421052631579, 0.6900584795321637, 0.7660818713450293, 0.7602339181286549]

# %% [markdown]
# # **Plot results**

# %% [markdown]
# ![faces_2.png](data:image/png;base64,...)

# %%
# Plot the prediction
#import packages and load datasets

import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml
from sklearn.neural_network import MLPClassifier
import numpy as np
from sklearn.model_selection import train_test_split

# tu rysujemy twarze
# tu rysujemy twarze
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(16, 16)) # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)
 
for i in range(100):
 ax = fig.add_subplot(10, 10, i + 1, xticks=[], yticks=[])
 ax.imshow(X_test[i].reshape(h,w), cmap=plt.cm.gray, interpolation='nearest')
 # label the image with the target value
 if expected[i]==predicted[i]:
    ax.text(0, 7, str(target_names[expected[i]])+" \n"+str(target_names[predicted[i]]), color='black')
 else:
     ax.text(0, 7, str(target_names[expected[i]])+" \n"+str(target_names[predicted[i]]), color='red')

# %% [markdown]
# Print the classification report

# %%
from sklearn import metrics
print(metrics.classification_report(expected, predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.84      0.87        64
#            1       0.66      0.72      0.69        32
#            2       0.88      0.91      0.90       127
#            3       0.74      0.79      0.77        29
#            4       0.89      0.73      0.80        33
#
#     accuracy                           0.84       285
#    macro avg       0.81      0.80      0.80       285
# weighted avg       0.85      0.84      0.84       285

# %% [markdown]
# # **Print the confusion matrix (expected true label vs. the reconstructed label)**

# %%
print(metrics.confusion_matrix(expected, predicted))
# Out:
# [[ 54   4   4   0   2]
#  [  1  23   4   4   0]
#  [  1   6 116   3   1]
#  [  2   2   2  23   0]
#  [  2   0   6   1  24]]
